# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (16.0, 8.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/sascha/anaconda/lib/python3.5/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['uniform']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Propagating samples through the model function

# %% [markdown]
# Assume the measurement model, i.e. the relation between the input quantities and the measurand, to be given as
# $$ Y = f(X_1,X_2,\ldots,X_N) $$
#
# with joint PDF associated with the input quantities given as $g_{\mathbf{X}}(\mathbf{\xi})$.

# %% [markdown]
# The aim of the Monte Carlo method is the propagation of samples from the PDF $g_{\mathbf{X}}(\mathbf{\xi})$ through the measurement model $f()$ as a means to calculate samples from the PDF $g_{Y}(\eta)$.

# %% [markdown]
# Basically, two types of implementation have to be considered: for-loops and vectorisation.

# %% [markdown]
# #### Monte Carlo using for-loops
#
# This is the most easiest way of implementing Monte Carlo for a given function $f()$.
#
# ``` python
#     Y = np.zeros(number_of_runs)
#     X1,X2,...,XN = draw_from_gX(number_of_runs)
#     for k in range(number_of_runs):
#         Y[k] = model_function(X1[k],X2[k],...,XN[k])
# ```

# %% [markdown]
# #### Monte Carlo using vectorisation
#
# For scripting languages, such as Python, Matlab or LabView, a for-loop is often very inefficient. Instead, a vectorisation of the model function should be considered.
#
# For instance, let the model function be
# $$ Y = X_1 \sin (2\pi X_2) - X_3^2 $$
#
# The vectorized Monte Carlo method for this model is given as
# ``` python
#     X1,X2,X3 = draw_from_gX(number_of_runs)
#     Y = X1*np.sin(2*np.pi*X2) - X3**2
# ```

# %% [markdown]
# ### Exercise 3.1
#
# Carry out a Monte Carlo propagation of samples through the model
# $$ Y = \frac{X_2^2}{\sqrt{1-X_1^2}}$$
# with knowledge about the input quantities given as
#
# * The value of $X_1$ satisfies $-0.8 \leq x_1 \leq  0.8$
#
# * $X_2$ has best estimate $x_2 = 3.4$ with associated standard uncertainty $\sigma=0.5$ determined from 12 repeated measurements

# %%
from scipy.stats import uniform, t
t?

# %%
from scipy.stats import uniform, t

draws = 10000
a = -0.8
b = 0.8
X1 = uniform.rvs(loc=a, scale=b-a, size=draws)

dof = 11
mu = 3.4
sigma = 0.5
X2 = t.rvs(dof, loc=mu, scale=sigma, size=draws)

Y = zeros(draws)

for k in range(draws):
    Y[k] = X2[k]**2 / sqrt(1-X1[k]**2)

hist(Y, bins=100, edgecolor="none");

# %%
y = mean(Y)
uy = std(Y)

ys = sort(Y)
q = int(len(Y)*0.95)
l = int(0.5*(len(Y)-q))
r = int(l + q)

yl = ys[l]
yr = ys[r]


print("best estimate %g"%y)
print("standard uncertainty %g"%uy)
print("95%% coverage interval [%g, %g]"%(yl, yr))
# Out:
# best estimate 13.7356
# standard uncertainty 4.78151
# 95% coverage interval [5.97645, 24.8483]

# %% [markdown]
# ### Exercise 3.2
#
# Carry out a Monte Carlo propagation for the following parameter estimation problem.
#
# For a measurement device under test, a parametrised calibration curve is to be determined by means of a non-linear least-squares fit to a set of measured pairs $(t_i, x_i)$ assuming as functional relationship
# $$ x_i = f(t_i) = a\cdot\exp (-b t_i)\cdot \sin (c t_i) $$
# The measurement data is assumed to be disturbed by white noise with a standard deviation of $\sigma=0.3$. The values $x_i$ are all assumed to be obtained independently, i.e. to be uncorrelated.
#
# For the fitting of the parameters use
# ``` python
#     from scipy.optimize import curve_fit
#
#     noise = sigma*ones_like(x)
#     phat,cphat = curve_fit(modelfun, t, x, sigma=noise)
# ```

# %%
data = loadtxt("test_data.txt",delimiter=",")
t = data[:,0]
x = data[:,1]
# alternatively: t = linspace(0,5,25); x = 5.0 * exp(-0.5*t) * sin(2*pi*t) + random.randn(len(t))*0.3
sigma = 0.3
errorbar(t,x,sigma*ones_like(t),fmt="o");

# %%
from scipy.optimize import curve_fit
curve_fit?

# %%
noise = 0.2
modelfun = lambda ti,a,b,c: a*exp(-b*ti)*sin(c*ti) 

# linearization result (à la GUM)
phat,uphat = curve_fit(modelfun, t, x, sigma=noise)

# %%
phat
# Out:
# array([ 5.20759009,  0.51232164,  6.26031862])

# %%
uphat
# Out:
# array([[  3.93750041e-02,   4.23217994e-03,  -3.43454645e-05],
#        [  4.23217994e-03,   8.49207367e-04,  -7.63166480e-06],
#        [ -3.43454645e-05,  -7.63166480e-06,   3.96295772e-04]])

# %%
from scipy.stats import norm, multivariate_normal
draws = 10000
noise = 0.3

# Ziehen der Eingangsgrößen
X = zeros((draws, len(x)))
for k in range(len(x)):
    X[:, k] = norm.rvs(size=draws, loc=x[k], scale=sigma)

X2 = multivariate_normal.rvs(size=draws, mean=x, cov=sigma**2*eye(len(x)))

# for-Schleife für Monte Carlo
Phat = zeros((3, draws))
for k in range(draws):
    Phat[:,k] = curve_fit(modelfun, t, X[k,:], sigma=noise)[0]
    
# Histogrammplot der Messgröße
figure(1)
hist(Phat[0,:],bins=100)
axvline(phat[0])

figure(2)
hist(Phat[1,:],bins=100)
axvline(phat[1])

figure(3)
hist(Phat[2,:],bins=100);
axvline(phat[2]);
# Out:
# [<matplotlib.lines.Line2D at 0x110b85588>,
#  <matplotlib.lines.Line2D at 0x116df9d30>,
#  <matplotlib.lines.Line2D at 0x116df9b70>,
#  <matplotlib.lines.Line2D at 0x116df9c88>,
#  <matplotlib.lines.Line2D at 0x116c64ba8>,
#  <matplotlib.lines.Line2D at 0x116c64c18>,
#  <matplotlib.lines.Line2D at 0x116c64c50>,
#  <matplotlib.lines.Line2D at 0x116c64080>,
#  <matplotlib.lines.Line2D at 0x116c64898>,
#  <matplotlib.lines.Line2D at 0x116c64208>,
#  <matplotlib.lines.Line2D at 0x116c64fd0>,
#  <matplotlib.lines.Line2D at 0x110b984e0>,
#  <matplotlib.lines.Line2D at 0x110b982e8>,
#  <matplotlib.lines.Line2D at 0x110b98c18>,
#  <matplotlib.lines.Line2D at 0x110b98d68>,
#  <matplotlib.lines.Line2D at 0x110b98550>,
#  <matplotlib.lines.Line2D at 0x110b98c88>,
#  <matplotlib.lines.Line2D at 0x110b98a58>,
#  <matplotlib.lines.Line2D at 0x110b98080>,
#  <matplotlib.lines.Line2D at 0x116dfe1d0>,
#  <matplotlib.lines.Line2D at 0x116dfe748>,
#  <matplotlib.lines.Line2D at 0x116dfe9b0>,
#  <matplotlib.lines.Line2D at 0x116dfe7f0>,
#  <matplotlib.lines.Line2D at 0x116dfeba8>,
#  <matplotlib.lines.Line2D at 0x116dfef98>,
#  <matplotlib.lines.Line2D at 0x116dfec50>,
#  <matplotlib.lines.Line2D at 0x116dfea58>,
#  <matplotlib.lines.Line2D at 0x116f07048>,
#  <matplotlib.lines.Line2D at 0x116f073c8>,
#  <matplotlib.lines.Line2D at 0x116f07a20>,
#  <matplotlib.lines.Line2D at 0x116f07c88>,
#  <matplotlib.lines.Line2D at 0x116f07518>,
#  <matplotlib.lines.Line2D at 0x116f07748>,
#  <matplotlib.lines.Line2D at 0x116f077b8>,
#  <matplotlib.lines.Line2D at 0x10e78eb38>,
#  <matplotlib.lines.Line2D at 0x10e78ed30>,
#  <matplotlib.lines.Line2D at 0x10e78e390>,
#  <matplotlib.lines.Line2D at 0x10e78ef28>,
#  <matplotlib.lines.Line2D at 0x10e78e0b8>,
#  <matplotlib.lines.Line2D at 0x10e78e3c8>,
#  <matplotlib.lines.Line2D at 0x116dd5198>,
#  <matplotlib.lines.Line2D at 0x116dd54a8>,
#  <matplotlib.lines.Line2D at 0x116dd5710>,
#  <matplotlib.lines.Line2D at 0x116dd5438>,
#  <matplotlib.lines.Line2D at 0x11370eb00>,
#  <matplotlib.lines.Line2D at 0x11370ed68>,
#  <matplotlib.lines.Line2D at 0x113fa80f0>,
#  <matplotlib.lines.Line2D at 0x116c5df60>,
#  <matplotlib.lines.Line2D at 0x111e2b588>,
#  <matplotlib.lines.Line2D at 0x1116e85c0>,
#  <matplotlib.lines.Line2D at 0x1116e8c88>,
#  <matplotlib.lines.Line2D at 0x1130691d0>,
#  <matplotlib.lines.Line2D at 0x113069ef0>,
#  <matplotlib.lines.Line2D at 0x116dd59b0>,
#  <matplotlib.lines.Line2D at 0x116dd5630>,
#  <matplotlib.lines.Line2D at 0x116dd5e80>,
#  <matplotlib.lines.Line2D at 0x116dd5390>,
#  <matplotlib.lines.Line2D at 0x111e1a898>,
#  <matplotlib.lines.Line2D at 0x111e1a860>,
#  <matplotlib.lines.Line2D at 0x111e1a438>,
#  <matplotlib.lines.Line2D at 0x111e1aef0>,
#  <matplotlib.lines.Line2D at 0x111e1a978>,
#  <matplotlib.lines.Line2D at 0x111e1a7f0>,
#  <matplotlib.lines.Line2D at 0x111e1a358>,
#  <matplotlib.lines.Line2D at 0x116f13518>,
#  <matplotlib.lines.Line2D at 0x116f134a8>,
#  <matplotlib.lines.Line2D at 0x116f13390>,
#  <matplotlib.lines.Line2D at 0x116f13cc0>,
#  <matplotlib.lines.Line2D at 0x116f13d30>,
#  <matplotlib.lines.Line2D at 0x116f13128>,
#  <matplotlib.lines.Line2D at 0x116f139e8>,
#  <matplotlib.lines.Line2D at 0x116f18320>,
#  <matplotlib.lines.Line2D at 0x116f187b8>,
#  <matplotlib.lines.Line2D at 0x116f180b8>,
#  <matplotlib.lines.Line2D at 0x116f18550>,
#  <matplotlib.lines.Line2D at 0x116f18fd0>,
#  <matplotlib.lines.Line2D at 0x116f18e10>,
#  <matplotlib.lines.Line2D at 0x116f18a90>,
#  <matplotlib.lines.Line2D at 0x116f189b0>,
#  <matplotlib.lines.Line2D at 0x116f1d0b8>,
#  <matplotlib.lines.Line2D at 0x116f1d898>,
#  <matplotlib.lines.Line2D at 0x116f1d828>,
#  <matplotlib.lines.Line2D at 0x116f1d6d8>,
#  <matplotlib.lines.Line2D at 0x116f1dcf8>,
#  <matplotlib.lines.Line2D at 0x116f1d630>,
#  <matplotlib.lines.Line2D at 0x116f1ddd8>,
#  <matplotlib.lines.Line2D at 0x116f25ef0>,
#  <matplotlib.lines.Line2D at 0x116f252b0>,
#  <matplotlib.lines.Line2D at 0x116f25c50>,
#  <matplotlib.lines.Line2D at 0x116f254a8>,
#  <matplotlib.lines.Line2D at 0x116f25400>,
#  <matplotlib.lines.Line2D at 0x116f25d68>,
#  <matplotlib.lines.Line2D at 0x116f25e10>,
#  <matplotlib.lines.Line2D at 0x116f25668>,
#  <matplotlib.lines.Line2D at 0x110bb3160>,
#  <matplotlib.lines.Line2D at 0x110bb39b0>,
#  <matplotlib.lines.Line2D at 0x110bb3438>,
#  <matplotlib.lines.Line2D at 0x110bb3c50>,
#  <matplotlib.lines.Line2D at 0x110bb3fd0>,
#  <matplotlib.lines.Line2D at 0x110bb3668>,
#  <matplotlib.lines.Line2D at 0x110bb3e80>,
#  <matplotlib.lines.Line2D at 0x110bb35f8>,
#  <matplotlib.lines.Line2D at 0x116f2e160>,
#  <matplotlib.lines.Line2D at 0x116f2e2e8>,
#  <matplotlib.lines.Line2D at 0x116f2ed68>,
#  <matplotlib.lines.Line2D at 0x116f2e5c0>,
#  <matplotlib.lines.Line2D at 0x116f2e518>,
#  <matplotlib.lines.Line2D at 0x116f2e358>,
#  <matplotlib.lines.Line2D at 0x116f2e7b8>,
#  <matplotlib.lines.Line2D at 0x116f2ed30>,
#  <matplotlib.lines.Line2D at 0x116f382b0>,
#  <matplotlib.lines.Line2D at 0x116f386a0>,
#  <matplotlib.lines.Line2D at 0x116f38eb8>,
#  <matplotlib.lines.Line2D at 0x116f38da0>,
#  <matplotlib.lines.Line2D at 0x116f38b70>,
#  <matplotlib.lines.Line2D at 0x116f38208>,
#  <matplotlib.lines.Line2D at 0x116f38978>,
#  <matplotlib.lines.Line2D at 0x116f3e4e0>,
#  <matplotlib.lines.Line2D at 0x116f3e518>,
#  <matplotlib.lines.Line2D at 0x116f3e400>,
#  <matplotlib.lines.Line2D at 0x116f3eef0>,
#  <matplotlib.lines.Line2D at 0x116f3e8d0>,
#  <matplotlib.lines.Line2D at 0x116f3ecf8>,
#  <matplotlib.lines.Line2D at 0x116f3e9e8>,
#  <matplotlib.lines.Line2D at 0x116f3e908>,
#  <matplotlib.lines.Line2D at 0x116f43320>,
#  <matplotlib.lines.Line2D at 0x116f43390>,
#  <matplotlib.lines.Line2D at 0x116f43358>,
#  <matplotlib.lines.Line2D at 0x116f435f8>,
#  <matplotlib.lines.Line2D at 0x116f43a90>,
#  <matplotlib.lines.Line2D at 0x116f43400>,
#  <matplotlib.lines.Line2D at 0x116f43cc0>,
#  <matplotlib.lines.Line2D at 0x116f4a2e8>,
#  <matplotlib.lines.Line2D at 0x116f4a160>,
#  <matplotlib.lines.Line2D at 0x116f4a9b0>,
#  <matplotlib.lines.Line2D at 0x116f4a940>,
#  <matplotlib.lines.Line2D at 0x116f4a7f0>,
#  <matplotlib.lines.Line2D at 0x116f4ac18>,
#  <matplotlib.lines.Line2D at 0x116f4aa58>,
#  <matplotlib.lines.Line2D at 0x116f4ac88>,
#  <matplotlib.lines.Line2D at 0x116f502b0>,
#  <matplotlib.lines.Line2D at 0x116f50160>,
#  <matplotlib.lines.Line2D at 0x116f50860>,
#  <matplotlib.lines.Line2D at 0x116f50c88>,
#  <matplotlib.lines.Line2D at 0x116f50ac8>,
#  <matplotlib.lines.Line2D at 0x116f50e80>,
#  <matplotlib.lines.Line2D at 0x116f50780>,
#  <matplotlib.lines.Line2D at 0x116f50d30>,
#  <matplotlib.lines.Line2D at 0x116f572b0>,
#  <matplotlib.lines.Line2D at 0x116f576a0>,
#  <matplotlib.lines.Line2D at 0x116f57eb8>,
#  <matplotlib.lines.Line2D at 0x116f57da0>,
#  <matplotlib.lines.Line2D at 0x116f57b70>,
#  <matplotlib.lines.Line2D at 0x116f57208>,
#  <matplotlib.lines.Line2D at 0x116f57978>,
#  <matplotlib.lines.Line2D at 0x116f5e4e0>,
#  <matplotlib.lines.Line2D at 0x116f5e518>,
#  <matplotlib.lines.Line2D at 0x116f5e400>,
#  <matplotlib.lines.Line2D at 0x116f5eef0>,
#  <matplotlib.lines.Line2D at 0x116f5e8d0>,
#  <matplotlib.lines.Line2D at 0x116f5ecf8>,
#  <matplotlib.lines.Line2D at 0x116f5e9e8>,
#  <matplotlib.lines.Line2D at 0x116f5e908>,
#  <matplotlib.lines.Line2D at 0x116f62320>,
#  <matplotlib.lines.Line2D at 0x116f62390>,
#  <matplotlib.lines.Line2D at 0x116f62358>,
#  <matplotlib.lines.Line2D at 0x116f625f8>,
#  <matplotlib.lines.Line2D at 0x116f62a90>,
#  <matplotlib.lines.Line2D at 0x116f62400>,
#  <matplotlib.lines.Line2D at 0x116f62208>,
#  <matplotlib.lines.Line2D at 0x116f6e048>,
#  <matplotlib.lines.Line2D at 0x116f6e198>,
#  <matplotlib.lines.Line2D at 0x116f6e208>,
#  <matplotlib.lines.Line2D at 0x116f6eb70>,
#  <matplotlib.lines.Line2D at 0x116f6eb00>,
#  <matplotlib.lines.Line2D at 0x116f6e9b0>,
#  <matplotlib.lines.Line2D at 0x116f6e668>,
#  <matplotlib.lines.Line2D at 0x116f6ef28>,
#  <matplotlib.lines.Line2D at 0x113f97c50>,
#  <matplotlib.lines.Line2D at 0x113f97908>,
#  <matplotlib.lines.Line2D at 0x113f97390>,
#  <matplotlib.lines.Line2D at 0x113f97278>,
#  <matplotlib.lines.Line2D at 0x113f97dd8>,
#  <matplotlib.lines.Line2D at 0x113f977f0>,
#  <matplotlib.lines.Line2D at 0x113f973c8>,
#  <matplotlib.lines.Line2D at 0x116f747b8>,
#  <matplotlib.lines.Line2D at 0x116f74358>,
#  <matplotlib.lines.Line2D at 0x116f743c8>,
#  <matplotlib.lines.Line2D at 0x116f74eb8>,
#  <matplotlib.lines.Line2D at 0x116f74da0>,
#  <matplotlib.lines.Line2D at 0x116f74b70>,
#  <matplotlib.lines.Line2D at 0x116f74208>,
#  <matplotlib.lines.Line2D at 0x116f74978>,
#  <matplotlib.lines.Line2D at 0x116fa5f60>,
#  <matplotlib.lines.Line2D at 0x116fa5208>,
#  <matplotlib.lines.Line2D at 0x116fa5b00>,
#  <matplotlib.lines.Line2D at 0x116fa59e8>,
#  <matplotlib.lines.Line2D at 0x116fa56d8>,
#  <matplotlib.lines.Line2D at 0x116fa5f98>,
#  <matplotlib.lines.Line2D at 0x116fa55f8>,
#  <matplotlib.lines.Line2D at 0x116fa5ef0>,
#  <matplotlib.lines.Line2D at 0x112a00ac8>,
#  <matplotlib.lines.Line2D at 0x112a0cd68>,
#  <matplotlib.lines.Line2D at 0x112a052e8>,
#  <matplotlib.lines.Line2D at 0x11259d048>,
#  <matplotlib.lines.Line2D at 0x112019dd8>,
#  <matplotlib.lines.Line2D at 0x1120bc9e8>,
#  <matplotlib.lines.Line2D at 0x117037128>,
#  <matplotlib.lines.Line2D at 0x1170379e8>,
#  <matplotlib.lines.Line2D at 0x117037240>,
#  <matplotlib.lines.Line2D at 0x117037198>,
#  <matplotlib.lines.Line2D at 0x117037da0>,
#  <matplotlib.lines.Line2D at 0x117037ef0>,
#  <matplotlib.lines.Line2D at 0x117037438>,
#  <matplotlib.lines.Line2D at 0x11703cfd0>,
#  <matplotlib.lines.Line2D at 0x11703c588>,
#  <matplotlib.lines.Line2D at 0x11703c240>,
#  <matplotlib.lines.Line2D at 0x11703c080>,
#  <matplotlib.lines.Line2D at 0x11703ca90>,
#  <matplotlib.lines.Line2D at 0x11703c390>,
#  <matplotlib.lines.Line2D at 0x11703c828>,
#  <matplotlib.lines.Line2D at 0x11703cc18>,
#  <matplotlib.lines.Line2D at 0x111ebdcf8>,
#  <matplotlib.lines.Line2D at 0x116dc9ef0>,
#  <matplotlib.lines.Line2D at 0x116dc9f60>,
#  <matplotlib.lines.Line2D at 0x116dc9dd8>,
#  <matplotlib.lines.Line2D at 0x116dc9d30>,
#  <matplotlib.lines.Line2D at 0x116dc9208>,
#  <matplotlib.lines.Line2D at 0x116dc9080>,
#  <matplotlib.lines.Line2D at 0x116dc9908>,
#  <matplotlib.lines.Line2D at 0x116dc9b38>,
#  <matplotlib.lines.Line2D at 0x116dba898>,
#  <matplotlib.lines.Line2D at 0x116dba048>,
#  <matplotlib.lines.Line2D at 0x116dba9b0>,
#  <matplotlib.lines.Line2D at 0x116dbabe0>,
#  <matplotlib.lines.Line2D at 0x116dbab38>,
#  <matplotlib.lines.Line2D at 0x116dba128>,
#  <matplotlib.lines.Line2D at 0x116dba390>,
#  <matplotlib.lines.Line2D at 0x10bdf4048>,
#  <matplotlib.lines.Line2D at 0x10bdf4b00>,
#  <matplotlib.lines.Line2D at 0x10bdf41d0>,
#  <matplotlib.lines.Line2D at 0x10bdf4f28>,
#  <matplotlib.lines.Line2D at 0x10bdf4ef0>,
#  <matplotlib.lines.Line2D at 0x10bdf47b8>,
#  <matplotlib.lines.Line2D at 0x10bdf4630>,
#  <matplotlib.lines.Line2D at 0x10bdf4668>,
#  <matplotlib.lines.Line2D at 0x116c264a8>,
#  <matplotlib.lines.Line2D at 0x116c269e8>,
#  <matplotlib.lines.Line2D at 0x116c26eb8>,
#  <matplotlib.lines.Line2D at 0x116c26358>,
#  <matplotlib.lines.Line2D at 0x116c267f0>,
#  <matplotlib.lines.Line2D at 0x116c265f8>,
#  <matplotlib.lines.Line2D at 0x116c26438>,
#  <matplotlib.lines.Line2D at 0x116c262e8>,
#  <matplotlib.lines.Line2D at 0x11359a5f8>,
#  <matplotlib.lines.Line2D at 0x11359a438>,
#  <matplotlib.lines.Line2D at 0x11359a128>,
#  <matplotlib.lines.Line2D at 0x11359ac88>,
#  <matplotlib.lines.Line2D at 0x11359aef0>,
#  <matplotlib.lines.Line2D at 0x11359af28>,
#  <matplotlib.lines.Line2D at 0x11359a7b8>,
#  <matplotlib.lines.Line2D at 0x11359a6d8>,
#  <matplotlib.lines.Line2D at 0x11358e048>,
#  <matplotlib.lines.Line2D at 0x11358e780>,
#  <matplotlib.lines.Line2D at 0x11358e710>,
#  <matplotlib.lines.Line2D at 0x11358e5c0>,
#  <matplotlib.lines.Line2D at 0x11358ea20>,
#  <matplotlib.lines.Line2D at 0x11358ee48>,
#  <matplotlib.lines.Line2D at 0x11358eb38>,
#  <matplotlib.lines.Line2D at 0x11358e080>,
#  <matplotlib.lines.Line2D at 0x1125c94e0>,
#  <matplotlib.lines.Line2D at 0x1125c9208>,
#  <matplotlib.lines.Line2D at 0x1125c9e10>,
#  <matplotlib.lines.Line2D at 0x1125c9cf8>,
#  <matplotlib.lines.Line2D at 0x1125c99e8>,
#  <matplotlib.lines.Line2D at 0x1125c9198>,
#  <matplotlib.lines.Line2D at 0x1125c9080>,
#  <matplotlib.lines.Line2D at 0x1125c9e80>,
#  <matplotlib.lines.Line2D at 0x1170a0240>,
#  <matplotlib.lines.Line2D at 0x1170a0278>,
#  <matplotlib.lines.Line2D at 0x1170a0ef0>,
#  <matplotlib.lines.Line2D at 0x1170a0048>,
#  <matplotlib.lines.Line2D at 0x1170a0d30>,
#  <matplotlib.lines.Line2D at 0x1170a0ac8>,
#  <matplotlib.lines.Line2D at 0x1170a04a8>,
#  <matplotlib.lines.Line2D at 0x1137c6eb8>,
#  <matplotlib.lines.Line2D at 0x1137c6e80>,
#  <matplotlib.lines.Line2D at 0x1137c62e8>,
#  <matplotlib.lines.Line2D at 0x1137c60b8>,
#  <matplotlib.lines.Line2D at 0x1137c61d0>,
#  <matplotlib.lines.Line2D at 0x1137c6a90>,
#  <matplotlib.lines.Line2D at 0x1137c65c0>,
#  <matplotlib.lines.Line2D at 0x1137c6860>,
#  <matplotlib.lines.Line2D at 0x1125d23c8>,
#  <matplotlib.lines.Line2D at 0x1125d21d0>,
#  <matplotlib.lines.Line2D at 0x1125d27f0>,
#  <matplotlib.lines.Line2D at 0x1125d2c18>,
#  <matplotlib.lines.Line2D at 0x1125d2a58>,
#  <matplotlib.lines.Line2D at 0x1125d2e10>,
#  <matplotlib.lines.Line2D at 0x1125d2710>,
#  <matplotlib.lines.Line2D at 0x1125d2cc0>,
#  <matplotlib.lines.Line2D at 0x1137bc208>,
#  <matplotlib.lines.Line2D at 0x1137bc748>,
#  <matplotlib.lines.Line2D at 0x1137bc9b0>,
#  <matplotlib.lines.Line2D at 0x1137bc240>,
#  <matplotlib.lines.Line2D at 0x1137bcba8>,
#  <matplotlib.lines.Line2D at 0x1137bc6a0>,
#  <matplotlib.lines.Line2D at 0x1137bcc50>,
#  <matplotlib.lines.Line2D at 0x1137bc940>,
#  <matplotlib.lines.Line2D at 0x11378f048>,
#  <matplotlib.lines.Line2D at 0x11378fb38>,
#  <matplotlib.lines.Line2D at 0x11378f390>,
#  <matplotlib.lines.Line2D at 0x11378f2e8>,
#  <matplotlib.lines.Line2D at 0x11378fc50>,
#  <matplotlib.lines.Line2D at 0x11378f9e8>,
#  <matplotlib.lines.Line2D at 0x11378ff98>,
#  <matplotlib.lines.Line2D at 0x11378fb00>,
#  <matplotlib.lines.Line2D at 0x11220e588>,
#  <matplotlib.lines.Line2D at 0x116d14908>,
#  <matplotlib.lines.Line2D at 0x116d140b8>,
#  <matplotlib.lines.Line2D at 0x116d14358>,
#  <matplotlib.lines.Line2D at 0x116d14ba8>,
#  <matplotlib.lines.Line2D at 0x116d14860>,
#  <matplotlib.lines.Line2D at 0x116d14518>,
#  <matplotlib.lines.Line2D at 0x116d14e10>,
#  <matplotlib.lines.Line2D at 0x116d14a90>,
#  <matplotlib.lines.Line2D at 0x113779080>,
#  <matplotlib.lines.Line2D at 0x113779470>,
#  <matplotlib.lines.Line2D at 0x1137795f8>,
#  <matplotlib.lines.Line2D at 0x1137799b0>,
#  <matplotlib.lines.Line2D at 0x113779a20>,
#  <matplotlib.lines.Line2D at 0x113779ef0>,
#  <matplotlib.lines.Line2D at 0x1137796a0>,
#  <matplotlib.lines.Line2D at 0x110bcc2b0>,
#  <matplotlib.lines.Line2D at 0x110bcc198>,
#  <matplotlib.lines.Line2D at 0x110bcc668>,
#  <matplotlib.lines.Line2D at 0x110bcc320>,
#  <matplotlib.lines.Line2D at 0x110bcc1d0>,
#  <matplotlib.lines.Line2D at 0x110bcc470>,
#  <matplotlib.lines.Line2D at 0x113778940>,
#  <matplotlib.lines.Line2D at 0x113778198>,
#  <matplotlib.lines.Line2D at 0x1137780f0>,
#  <matplotlib.lines.Line2D at 0x113778fd0>,
#  <matplotlib.lines.Line2D at 0x113778d30>,
#  <matplotlib.lines.Line2D at 0x1137784a8>,
#  <matplotlib.lines.Line2D at 0x113778d68>,
#  <matplotlib.lines.Line2D at 0x117068e48>,
#  <matplotlib.lines.Line2D at 0x1170684e0>,
#  <matplotlib.lines.Line2D at 0x117068080>,
#  <matplotlib.lines.Line2D at 0x117068320>,
#  <matplotlib.lines.Line2D at 0x117068668>,
#  <matplotlib.lines.Line2D at 0x117068438>,
#  <matplotlib.lines.Line2D at 0x1170689b0>,
#  <matplotlib.lines.Line2D at 0x117068240>,
#  <matplotlib.lines.Line2D at 0x113203fd0>,
#  <matplotlib.lines.Line2D at 0x1132034a8>,
#  <matplotlib.lines.Line2D at 0x1132031d0>,
#  <matplotlib.lines.Line2D at 0x113203710>,
#  <matplotlib.lines.Line2D at 0x113203da0>,
#  <matplotlib.lines.Line2D at 0x113203be0>,
#  <matplotlib.lines.Line2D at 0x113203470>,
#  <matplotlib.lines.Line2D at 0x113203d30>,
#  <matplotlib.lines.Line2D at 0x1132020b8>,
#  <matplotlib.lines.Line2D at 0x113202550>,
#  <matplotlib.lines.Line2D at 0x113202358>,
#  <matplotlib.lines.Line2D at 0x113202fd0>,
#  <matplotlib.lines.Line2D at 0x113202eb8>,
#  <matplotlib.lines.Line2D at 0x113202cc0>,
#  <matplotlib.lines.Line2D at 0x113202278>,
#  <matplotlib.lines.Line2D at 0x1132022e8>,
#  <matplotlib.lines.Line2D at 0x11365a080>,
#  <matplotlib.lines.Line2D at 0x11365a748>,
#  <matplotlib.lines.Line2D at 0x11365a6d8>,
#  <matplotlib.lines.Line2D at 0x11365a588>,
#  <matplotlib.lines.Line2D at 0x11365aef0>,
#  <matplotlib.lines.Line2D at 0x11365ae48>,
#  <matplotlib.lines.Line2D at 0x11365a438>,
#  <matplotlib.lines.Line2D at 0x11365a4e0>,
#  <matplotlib.lines.Line2D at 0x113652048>,
#  <matplotlib.lines.Line2D at 0x1136525c0>,
#  <matplotlib.lines.Line2D at 0x113652a20>,
#  <matplotlib.lines.Line2D at 0x113652860>,
#  <matplotlib.lines.Line2D at 0x113652b70>,
#  <matplotlib.lines.Line2D at 0x113652ba8>,
#  <matplotlib.lines.Line2D at 0x113652cc0>,
#  <matplotlib.lines.Line2D at 0x113652208>,
#  <matplotlib.lines.Line2D at 0x111e26fd0>,
#  <matplotlib.lines.Line2D at 0x111e26e80>,
#  <matplotlib.lines.Line2D at 0x111e26d30>,
#  <matplotlib.lines.Line2D at 0x111e261d0>,
#  <matplotlib.lines.Line2D at 0x111e26dd8>,
#  <matplotlib.lines.Line2D at 0x111e26c50>,
#  <matplotlib.lines.Line2D at 0x111e26208>,
#  <matplotlib.lines.Line2D at 0x113671400>,
#  <matplotlib.lines.Line2D at 0x113671240>,
#  <matplotlib.lines.Line2D at 0x113671550>,
#  <matplotlib.lines.Line2D at 0x113671be0>,
#  <matplotlib.lines.Line2D at 0x113671a20>,
#  <matplotlib.lines.Line2D at 0x113671dd8>,
#  <matplotlib.lines.Line2D at 0x113671828>,
#  <matplotlib.lines.Line2D at 0x1136714e0>,
#  <matplotlib.lines.Line2D at 0x1136b52b0>,
#  <matplotlib.lines.Line2D at 0x1136b5278>,
#  <matplotlib.lines.Line2D at 0x1136b5400>,
#  <matplotlib.lines.Line2D at 0x1136b5dd8>,
#  <matplotlib.lines.Line2D at 0x1136b5f60>,
#  <matplotlib.lines.Line2D at 0x1136b50b8>,
#  <matplotlib.lines.Line2D at 0x1136b56a0>,
#  <matplotlib.lines.Line2D at 0x1136b57b8>,
#  <matplotlib.lines.Line2D at 0x11364f4a8>,
#  <matplotlib.lines.Line2D at 0x11364f1d0>,
#  <matplotlib.lines.Line2D at 0x11364fdd8>,
#  <matplotlib.lines.Line2D at 0x11364fcc0>,
#  <matplotlib.lines.Line2D at 0x11364f9b0>,
#  <matplotlib.lines.Line2D at 0x11364f940>,
#  <matplotlib.lines.Line2D at 0x11364f898>,
#  <matplotlib.lines.Line2D at 0x11364f9e8>,
#  <matplotlib.lines.Line2D at 0x113702128>,
#  <matplotlib.lines.Line2D at 0x1137021d0>,
#  <matplotlib.lines.Line2D at 0x113702978>,
#  <matplotlib.lines.Line2D at 0x113702dd8>,
#  <matplotlib.lines.Line2D at 0x113702ef0>,
#  <matplotlib.lines.Line2D at 0x113702438>,
#  <matplotlib.lines.Line2D at 0x113702278>,
#  <matplotlib.lines.Line2D at 0x1170a2748>,
#  <matplotlib.lines.Line2D at 0x1170a2160>,
#  <matplotlib.lines.Line2D at 0x1170a2358>,
#  <matplotlib.lines.Line2D at 0x1170a23c8>,
#  <matplotlib.lines.Line2D at 0x1170a2828>,
#  <matplotlib.lines.Line2D at 0x1170a2ac8>,
#  <matplotlib.lines.Line2D at 0x1170a2c88>,
#  <matplotlib.lines.Line2D at 0x1170a2ef0>,
#  <matplotlib.lines.Line2D at 0x1136de160>,
#  <matplotlib.lines.Line2D at 0x1136dea58>,
#  <matplotlib.lines.Line2D at 0x1136de278>,
#  <matplotlib.lines.Line2D at 0x1136de5f8>,
#  <matplotlib.lines.Line2D at 0x1136de780>,
#  <matplotlib.lines.Line2D at 0x1136de550>,
#  <matplotlib.lines.Line2D at 0x1136dee48>,
#  <matplotlib.lines.Line2D at 0x1136decf8>,
#  <matplotlib.lines.Line2D at 0x1136ea748>,
#  <matplotlib.lines.Line2D at 0x1136eaa58>,
#  <matplotlib.lines.Line2D at 0x1136eaf60>,
#  <matplotlib.lines.Line2D at 0x1136ea278>,
#  <matplotlib.lines.Line2D at 0x1136eac50>,
#  <matplotlib.lines.Line2D at 0x1136eacf8>,
#  <matplotlib.lines.Line2D at 0x1136ea780>,
#  <matplotlib.lines.Line2D at 0x1136ea6d8>,
#  <matplotlib.lines.Line2D at 0x1136e3588>,
#  <matplotlib.lines.Line2D at 0x1136e3630>,
#  <matplotlib.lines.Line2D at 0x1136e3550>,
#  <matplotlib.lines.Line2D at 0x1136e3080>,
#  <matplotlib.lines.Line2D at 0x1136e39e8>,
#  <matplotlib.lines.Line2D at 0x1136e3860>,
#  <matplotlib.lines.Line2D at 0x1136e3d30>,
#  <matplotlib.lines.Line2D at 0x1136e3e10>,
#  <matplotlib.lines.Line2D at 0x115b72d30>,
#  <matplotlib.lines.Line2D at 0x115b72780>,
#  <matplotlib.lines.Line2D at 0x115b72438>,
#  <matplotlib.lines.Line2D at 0x115b72cc0>,
#  <matplotlib.lines.Line2D at 0x115b72048>,
#  <matplotlib.lines.Line2D at 0x115b725c0>,
#  <matplotlib.lines.Line2D at 0x115b72748>,
#  <matplotlib.lines.Line2D at 0x115b72390>,
#  <matplotlib.lines.Line2D at 0x115b92240>,
#  <matplotlib.lines.Line2D at 0x115b926d8>,
#  <matplotlib.lines.Line2D at 0x115b920b8>,
#  <matplotlib.lines.Line2D at 0x115b92710>,
#  <matplotlib.lines.Line2D at 0x115b92588>,
#  <matplotlib.lines.Line2D at 0x115b92f60>,
#  <matplotlib.lines.Line2D at 0x115b92390>,
#  <matplotlib.lines.Line2D at 0x115ba3be0>,
#  <matplotlib.lines.Line2D at 0x115ba30f0>,
#  <matplotlib.lines.Line2D at 0x115ba3438>,
#  <matplotlib.lines.Line2D at 0x115ba31d0>,
#  <matplotlib.lines.Line2D at 0x115ba3b00>,
#  <matplotlib.lines.Line2D at 0x115ba32e8>,
#  <matplotlib.lines.Line2D at 0x115ba3c88>,
#  <matplotlib.lines.Line2D at 0x115ba36a0>,
#  <matplotlib.lines.Line2D at 0x11575ec88>,
#  <matplotlib.lines.Line2D at 0x11575e710>,
#  <matplotlib.lines.Line2D at 0x11575eb70>,
#  <matplotlib.lines.Line2D at 0x11575e400>,
#  <matplotlib.lines.Line2D at 0x11575ef98>,
#  <matplotlib.lines.Line2D at 0x11575e9e8>,
#  <matplotlib.lines.Line2D at 0x11575e550>,
#  <matplotlib.lines.Line2D at 0x11575e3c8>,
#  <matplotlib.lines.Line2D at 0x115792278>,
#  <matplotlib.lines.Line2D at 0x115792630>,
#  <matplotlib.lines.Line2D at 0x1157926a0>,
#  <matplotlib.lines.Line2D at 0x1157928d0>,
#  <matplotlib.lines.Line2D at 0x115792f28>,
#  <matplotlib.lines.Line2D at 0x115792438>,
#  <matplotlib.lines.Line2D at 0x115792390>,
#  <matplotlib.lines.Line2D at 0x115792518>,
#  <matplotlib.lines.Line2D at 0x11577e080>,
#  <matplotlib.lines.Line2D at 0x11577e358>,
#  <matplotlib.lines.Line2D at 0x11577e160>,
#  <matplotlib.lines.Line2D at 0x11577e6a0>,
#  <matplotlib.lines.Line2D at 0x11577e390>,
#  <matplotlib.lines.Line2D at 0x11577eeb8>,
#  <matplotlib.lines.Line2D at 0x11577ecf8>,
#  <matplotlib.lines.Line2D at 0x11577ea90>,
#  <matplotlib.lines.Line2D at 0x115771240>,
#  <matplotlib.lines.Line2D at 0x1157716d8>,
#  <matplotlib.lines.Line2D at 0x1157710b8>,
#  <matplotlib.lines.Line2D at 0x115771710>,
#  <matplotlib.lines.Line2D at 0x115771588>,
#  <matplotlib.lines.Line2D at 0x115771f60>,
#  <matplotlib.lines.Line2D at 0x115771390>,
#  <matplotlib.lines.Line2D at 0x1170a9eb8>,
#  <matplotlib.lines.Line2D at 0x1170a9828>,
#  <matplotlib.lines.Line2D at 0x1170a90f0>,
#  <matplotlib.lines.Line2D at 0x1170a9358>,
#  <matplotlib.lines.Line2D at 0x1170a95f8>,
#  <matplotlib.lines.Line2D at 0x1170a9908>,
#  <matplotlib.lines.Line2D at 0x1170a9be0>,
#  <matplotlib.lines.Line2D at 0x1170a9c88>,
#  <matplotlib.lines.Line2D at 0x110ba7cf8>,
#  <matplotlib.lines.Line2D at 0x110ba7eb8>,
#  <matplotlib.lines.Line2D at 0x110ba79b0>,
#  <matplotlib.lines.Line2D at 0x110ba7710>,
#  <matplotlib.lines.Line2D at 0x110ba7898>,
#  <matplotlib.lines.Line2D at 0x110ba7860>,
#  <matplotlib.lines.Line2D at 0x110ba78d0>,
#  <matplotlib.lines.Line2D at 0x115781438>,
#  <matplotlib.lines.Line2D at 0x115781198>,
#  <matplotlib.lines.Line2D at 0x115781748>,
#  <matplotlib.lines.Line2D at 0x115781d68>,
#  <matplotlib.lines.Line2D at 0x115781da0>,
#  <matplotlib.lines.Line2D at 0x115781550>,
#  <matplotlib.lines.Line2D at 0x115781358>,
#  <matplotlib.lines.Line2D at 0x115781710>,
#  <matplotlib.lines.Line2D at 0x116d9feb8>,
#  <matplotlib.lines.Line2D at 0x116d9f0f0>,
#  <matplotlib.lines.Line2D at 0x116d9f978>,
#  <matplotlib.lines.Line2D at 0x116d9f400>,
#  <matplotlib.lines.Line2D at 0x116d9f080>,
#  <matplotlib.lines.Line2D at 0x116d9fba8>,
#  <matplotlib.lines.Line2D at 0x116d9fa20>,
#  <matplotlib.lines.Line2D at 0x116d9fef0>,
#  <matplotlib.lines.Line2D at 0x116da57b8>,
#  <matplotlib.lines.Line2D at 0x116da5ba8>,
#  <matplotlib.lines.Line2D at 0x116da5f28>,
#  <matplotlib.lines.Line2D at 0x116da5160>,
#  <matplotlib.lines.Line2D at 0x116da5438>,
#  <matplotlib.lines.Line2D at 0x116da5e80>,
#  <matplotlib.lines.Line2D at 0x116da5668>,
#  <matplotlib.lines.Line2D at 0x116da52e8>,
#  <matplotlib.lines.Line2D at 0x110d5d9b0>,
#  <matplotlib.lines.Line2D at 0x110d5d7f0>,
#  <matplotlib.lines.Line2D at 0x110d5d6a0>,
#  <matplotlib.lines.Line2D at 0x110d5dbe0>,
#  <matplotlib.lines.Line2D at 0x110d5d588>,
#  <matplotlib.lines.Line2D at 0x110d5da20>,
#  <matplotlib.lines.Line2D at 0x110d5da58>,
#  <matplotlib.lines.Line2D at 0x110bb9e80>,
#  <matplotlib.lines.Line2D at 0x110bb9588>,
#  <matplotlib.lines.Line2D at 0x110bb93c8>,
#  <matplotlib.lines.Line2D at 0x110bb9c88>,
#  <matplotlib.lines.Line2D at 0x110bb9e48>,
#  <matplotlib.lines.Line2D at 0x110bb9748>,
#  <matplotlib.lines.Line2D at 0x110bb92b0>,
#  <matplotlib.lines.Line2D at 0x1130b4a58>,
#  <matplotlib.lines.Line2D at 0x1130b4208>,
#  <matplotlib.lines.Line2D at 0x1130b41d0>,
#  <matplotlib.lines.Line2D at 0x1130b4400>,
#  <matplotlib.lines.Line2D at 0x1130b4908>,
#  <matplotlib.lines.Line2D at 0x1130b45f8>,
#  <matplotlib.lines.Line2D at 0x1130b4e48>,
#  <matplotlib.lines.Line2D at 0x1130b4898>,
#  <matplotlib.lines.Line2D at 0x113755f60>,
#  <matplotlib.lines.Line2D at 0x113755390>,
#  <matplotlib.lines.Line2D at 0x113755748>,
#  <matplotlib.lines.Line2D at 0x113755e48>,
#  <matplotlib.lines.Line2D at 0x113755128>,
#  <matplotlib.lines.Line2D at 0x113755f28>,
#  <matplotlib.lines.Line2D at 0x113755fd0>,
#  <matplotlib.lines.Line2D at 0x1137558d0>,
#  <matplotlib.lines.Line2D at 0x11706d358>,
#  <matplotlib.lines.Line2D at 0x11706d630>,
#  <matplotlib.lines.Line2D at 0x11706d048>,
#  <matplotlib.lines.Line2D at 0x11706d8d0>,
#  <matplotlib.lines.Line2D at 0x11706dba8>,
#  <matplotlib.lines.Line2D at 0x11706dcf8>,
#  <matplotlib.lines.Line2D at 0x11706d1d0>,
#  <matplotlib.lines.Line2D at 0x111e7b2e8>,
#  <matplotlib.lines.Line2D at 0x113793438>,
#  <matplotlib.lines.Line2D at 0x113793048>,
#  <matplotlib.lines.Line2D at 0x1137932b0>,
#  <matplotlib.lines.Line2D at 0x113793518>,
#  <matplotlib.lines.Line2D at 0x1137935f8>,
#  <matplotlib.lines.Line2D at 0x113793a58>,
#  <matplotlib.lines.Line2D at 0x1137930f0>,
#  <matplotlib.lines.Line2D at 0x113793e80>,
#  <matplotlib.lines.Line2D at 0x112c099b0>,
#  <matplotlib.lines.Line2D at 0x112c09c50>,
#  <matplotlib.lines.Line2D at 0x112c09a90>,
#  <matplotlib.lines.Line2D at 0x112c094a8>,
#  <matplotlib.lines.Line2D at 0x112c09198>,
#  <matplotlib.lines.Line2D at 0x112c09780>,
#  <matplotlib.lines.Line2D at 0x112c09160>,
#  <matplotlib.lines.Line2D at 0x113797390>,
#  <matplotlib.lines.Line2D at 0x1137970f0>,
#  <matplotlib.lines.Line2D at 0x113797e48>,
#  <matplotlib.lines.Line2D at 0x113797668>,
#  <matplotlib.lines.Line2D at 0x1137971d0>,
#  <matplotlib.lines.Line2D at 0x113797780>,
#  <matplotlib.lines.Line2D at 0x113797908>,
#  <matplotlib.lines.Line2D at 0x113797240>,
#  <matplotlib.lines.Line2D at 0x112a24ef0>,
#  <matplotlib.lines.Line2D at 0x1170780b8>,
#  <matplotlib.lines.Line2D at 0x1170788d0>,
#  <matplotlib.lines.Line2D at 0x117078860>,
#  <matplotlib.lines.Line2D at 0x1170789e8>,
#  <matplotlib.lines.Line2D at 0x117078438>,
#  <matplotlib.lines.Line2D at 0x1170783c8>,
#  <matplotlib.lines.Line2D at 0x117078e48>,
#  <matplotlib.lines.Line2D at 0x117078eb8>,
#  <matplotlib.lines.Line2D at 0x10e789b00>,
#  <matplotlib.lines.Line2D at 0x10e789ac8>,
#  <matplotlib.lines.Line2D at 0x10e7897b8>,
#  <matplotlib.lines.Line2D at 0x10e789eb8>,
#  <matplotlib.lines.Line2D at 0x10e789780>,
#  <matplotlib.lines.Line2D at 0x10e798668>,
#  <matplotlib.lines.Line2D at 0x10e798400>,
#  <matplotlib.lines.Line2D at 0x10e798b70>,
#  <matplotlib.lines.Line2D at 0x10e798dd8>,
#  <matplotlib.lines.Line2D at 0x10e798550>,
#  <matplotlib.lines.Line2D at 0x10e7989b0>,
#  <matplotlib.lines.Line2D at 0x111e09668>,
#  <matplotlib.lines.Line2D at 0x111e096d8>,
#  <matplotlib.lines.Line2D at 0x111e09320>,
#  <matplotlib.lines.Line2D at 0x111e097b8>,
#  <matplotlib.lines.Line2D at 0x111e09da0>,
#  <matplotlib.lines.Line2D at 0x10e7798d0>,
#  <matplotlib.lines.Line2D at 0x10e779b38>,
#  <matplotlib.lines.Line2D at 0x10e779e10>,
#  <matplotlib.lines.Line2D at 0x10e779eb8>,
#  <matplotlib.lines.Line2D at 0x10e779da0>,
#  <matplotlib.lines.Line2D at 0x10e779a58>,
#  <matplotlib.lines.Line2D at 0x10e7794e0>,
#  <matplotlib.lines.Line2D at 0x10e779fd0>,
#  <matplotlib.lines.Line2D at 0x10e794048>,
#  <matplotlib.lines.Line2D at 0x10e794ac8>,
#  <matplotlib.lines.Line2D at 0x10e7940b8>,
#  <matplotlib.lines.Line2D at 0x10e794e80>,
#  <matplotlib.lines.Line2D at 0x10e7949e8>,
#  <matplotlib.lines.Line2D at 0x10e794588>,
#  <matplotlib.lines.Line2D at 0x110bdf7f0>,
#  <matplotlib.lines.Line2D at 0x110d55898>,
#  <matplotlib.lines.Line2D at 0x110d55908>,
#  <matplotlib.lines.Line2D at 0x110d55d30>,
#  <matplotlib.lines.Line2D at 0x110d55fd0>,
#  <matplotlib.lines.Line2D at 0x110d55208>,
#  <matplotlib.lines.Line2D at 0x110d55470>,
#  <matplotlib.lines.Line2D at 0x110d552e8>,
#  <matplotlib.lines.Line2D at 0x11452ccc0>,
#  <matplotlib.lines.Line2D at 0x11452c5c0>,
#  <matplotlib.lines.Line2D at 0x11452c550>,
#  <matplotlib.lines.Line2D at 0x11452cfd0>,
#  <matplotlib.lines.Line2D at 0x11452cda0>,
#  <matplotlib.lines.Line2D at 0x1125d1940>,
#  <matplotlib.lines.Line2D at 0x1125d1320>,
#  <matplotlib.lines.Line2D at 0x1125d1128>,
#  <matplotlib.lines.Line2D at 0x1125d1400>,
#  <matplotlib.lines.Line2D at 0x1125d19b0>,
#  <matplotlib.lines.Line2D at 0x1125d1a20>,
#  <matplotlib.lines.Line2D at 0x1125d1c88>,
#  <matplotlib.lines.Line2D at 0x1125d1e10>,
#  <matplotlib.lines.Line2D at 0x112c16710>,
#  <matplotlib.lines.Line2D at 0x112c168d0>,
#  <matplotlib.lines.Line2D at 0x112c161d0>,
#  <matplotlib.lines.Line2D at 0x112c16c50>,
#  <matplotlib.lines.Line2D at 0x112c16a58>,
#  <matplotlib.lines.Line2D at 0x112c164a8>,
#  <matplotlib.lines.Line2D at 0x112c16160>,
#  <matplotlib.lines.Line2D at 0x1137857b8>,
#  <matplotlib.lines.Line2D at 0x113785f28>,
#  <matplotlib.lines.Line2D at 0x113785048>,
#  <matplotlib.lines.Line2D at 0x113785748>,
#  <matplotlib.lines.Line2D at 0x113785ac8>,
#  <matplotlib.lines.Line2D at 0x113785e80>,
#  <matplotlib.lines.Line2D at 0x113785358>,
#  <matplotlib.lines.Line2D at 0x113785a90>,
#  <matplotlib.lines.Line2D at 0x1125b3eb8>,
#  <matplotlib.lines.Line2D at 0x1125b3588>,
#  <matplotlib.lines.Line2D at 0x1125b3a20>,
#  <matplotlib.lines.Line2D at 0x1125b3358>,
#  <matplotlib.lines.Line2D at 0x1125b3630>,
#  <matplotlib.lines.Line2D at 0x110d79fd0>,
#  <matplotlib.lines.Line2D at 0x110d79780>,
#  <matplotlib.lines.Line2D at 0x110d79c88>,
#  <matplotlib.lines.Line2D at 0x110d79208>,
#  <matplotlib.lines.Line2D at 0x110d79588>,
#  <matplotlib.lines.Line2D at 0x110d79320>,
#  <matplotlib.lines.Line2D at 0x110d79860>,
#  <matplotlib.lines.Line2D at 0x110d79828>,
#  <matplotlib.lines.Line2D at 0x10e6f1a20>,
#  <matplotlib.lines.Line2D at 0x10e6f1908>,
#  <matplotlib.lines.Line2D at 0x10e6f1eb8>,
#  <matplotlib.lines.Line2D at 0x10e6f1518>,
#  <matplotlib.lines.Line2D at 0x10e6f10f0>,
#  <matplotlib.lines.Line2D at 0x10e6f14a8>,
#  <matplotlib.lines.Line2D at 0x10e6f16d8>,
#  <matplotlib.lines.Line2D at 0x10e6f1c18>,
#  <matplotlib.lines.Line2D at 0x106b05b00>,
#  <matplotlib.lines.Line2D at 0x112fa87b8>,
#  <matplotlib.lines.Line2D at 0x112fa8f28>,
#  <matplotlib.lines.Line2D at 0x112fa89e8>,
#  <matplotlib.lines.Line2D at 0x112fa8198>,
#  <matplotlib.lines.Line2D at 0x112fa8b70>,
#  <matplotlib.lines.Line2D at 0x112fa8c50>,
#  <matplotlib.lines.Line2D at 0x112fa8e10>,
#  <matplotlib.lines.Line2D at 0x1145247b8>,
#  <matplotlib.lines.Line2D at 0x114524438>,
#  <matplotlib.lines.Line2D at 0x114524b70>,
#  <matplotlib.lines.Line2D at 0x114524390>,
#  <matplotlib.lines.Line2D at 0x114524358>,
#  <matplotlib.lines.Line2D at 0x1145240b8>,
#  <matplotlib.lines.Line2D at 0x111dcdac8>,
#  <matplotlib.lines.Line2D at 0x111dcd4e0>,
#  <matplotlib.lines.Line2D at 0x111dcdc50>,
#  <matplotlib.lines.Line2D at 0x111dcd278>,
#  <matplotlib.lines.Line2D at 0x111dcd668>,
#  <matplotlib.lines.Line2D at 0x113f9db38>,
#  <matplotlib.lines.Line2D at 0x113f9d128>,
#  <matplotlib.lines.Line2D at 0x113f9dd30>,
#  <matplotlib.lines.Line2D at 0x113f9d588>,
#  <matplotlib.lines.Line2D at 0x113f9d898>,
#  <matplotlib.lines.Line2D at 0x113f9d5c0>,
#  <matplotlib.lines.Line2D at 0x113f9d978>,
#  <matplotlib.lines.Line2D at 0x113f9dd68>,
#  <matplotlib.lines.Line2D at 0x113fab240>,
#  <matplotlib.lines.Line2D at 0x113fab6d8>,
#  <matplotlib.lines.Line2D at 0x113fab828>,
#  <matplotlib.lines.Line2D at 0x113fab518>,
#  <matplotlib.lines.Line2D at 0x113faba90>,
#  <matplotlib.lines.Line2D at 0x113fabc18>,
#  <matplotlib.lines.Line2D at 0x113fab9b0>,
#  <matplotlib.lines.Line2D at 0x113fabbe0>,
#  <matplotlib.lines.Line2D at 0x113775198>,
#  <matplotlib.lines.Line2D at 0x113775908>,
#  <matplotlib.lines.Line2D at 0x113775828>,
#  <matplotlib.lines.Line2D at 0x113775048>,
#  <matplotlib.lines.Line2D at 0x113775d30>,
#  <matplotlib.lines.Line2D at 0x113775160>,
#  <matplotlib.lines.Line2D at 0x113775470>,
#  <matplotlib.lines.Line2D at 0x11294f668>,
#  <matplotlib.lines.Line2D at 0x112a98240>,
#  <matplotlib.lines.Line2D at 0x111719cf8>,
#  <matplotlib.lines.Line2D at 0x11371e128>,
#  <matplotlib.lines.Line2D at 0x11371e550>,
#  <matplotlib.lines.Line2D at 0x11371ef28>,
#  <matplotlib.lines.Line2D at 0x11371e1d0>,
#  <matplotlib.lines.Line2D at 0x11371e358>,
#  <matplotlib.lines.Line2D at 0x11371e7f0>,
#  <matplotlib.lines.Line2D at 0x11371e438>,
#  <matplotlib.lines.Line2D at 0x11371e470>,
#  <matplotlib.lines.Line2D at 0x113725e48>,
#  <matplotlib.lines.Line2D at 0x113725c50>,
#  <matplotlib.lines.Line2D at 0x1137257f0>,
#  <matplotlib.lines.Line2D at 0x113725630>,
#  <matplotlib.lines.Line2D at 0x113725dd8>,
#  <matplotlib.lines.Line2D at 0x113725780>,
#  <matplotlib.lines.Line2D at 0x113725400>,
#  <matplotlib.lines.Line2D at 0x113725e10>,
#  <matplotlib.lines.Line2D at 0x1120f3f28>,
#  <matplotlib.lines.Line2D at 0x1120f3a58>,
#  <matplotlib.lines.Line2D at 0x1120f3da0>,
#  <matplotlib.lines.Line2D at 0x1120f3a90>,
#  <matplotlib.lines.Line2D at 0x1120f3e10>,
#  <matplotlib.lines.Line2D at 0x1120f37b8>,
#  <matplotlib.lines.Line2D at 0x112aa3cf8>,
#  <matplotlib.lines.Line2D at 0x111e41ac8>,
#  <matplotlib.lines.Line2D at 0x1120fccf8>,
#  <matplotlib.lines.Line2D at 0x11296ef28>,
#  <matplotlib.lines.Line2D at 0x110d2a208>,
#  <matplotlib.lines.Line2D at 0x111dd2c88>,
#  <matplotlib.lines.Line2D at 0x111dd2048>,
#  <matplotlib.lines.Line2D at 0x111dd25f8>,
#  <matplotlib.lines.Line2D at 0x111dd2828>,
#  <matplotlib.lines.Line2D at 0x111dd2470>,
#  <matplotlib.lines.Line2D at 0x111dd2160>,
#  <matplotlib.lines.Line2D at 0x111e49320>,
#  <matplotlib.lines.Line2D at 0x111de9cc0>,
#  <matplotlib.lines.Line2D at 0x111de96a0>,
#  <matplotlib.lines.Line2D at 0x111de9d30>,
#  <matplotlib.lines.Line2D at 0x111de97f0>,
#  <matplotlib.lines.Line2D at 0x111de9438>,
#  <matplotlib.lines.Line2D at 0x111de9dd8>,
#  <matplotlib.lines.Line2D at 0x111de9828>,
#  <matplotlib.lines.Line2D at 0x111de9b38>,
#  <matplotlib.lines.Line2D at 0x112a49d68>,
#  <matplotlib.lines.Line2D at 0x112a674a8>,
#  <matplotlib.lines.Line2D at 0x112a85c18>,
#  <matplotlib.lines.Line2D at 0x112a33780>,
#  <matplotlib.lines.Line2D at 0x112a74f98>,
#  <matplotlib.lines.Line2D at 0x110d60ba8>,
#  <matplotlib.lines.Line2D at 0x110d60208>,
#  <matplotlib.lines.Line2D at 0x110d60048>,
#  <matplotlib.lines.Line2D at 0x110d60e80>,
#  <matplotlib.lines.Line2D at 0x110d60b38>,
#  <matplotlib.lines.Line2D at 0x110d604e0>,
#  <matplotlib.lines.Line2D at 0x110d60748>,
#  <matplotlib.lines.Line2D at 0x110d60128>,
#  <matplotlib.lines.Line2D at 0x112a559b0>,
#  <matplotlib.lines.Line2D at 0x1120fadd8>,
#  <matplotlib.lines.Line2D at 0x1120fa828>,
#  <matplotlib.lines.Line2D at 0x112a80ba8>,
#  <matplotlib.lines.Line2D at 0x112a50f98>,
#  <matplotlib.lines.Line2D at 0x110d63ac8>,
#  <matplotlib.lines.Line2D at 0x110d63e48>,
#  <matplotlib.lines.Line2D at 0x110d635f8>,
#  <matplotlib.lines.Line2D at 0x110d630f0>,
#  <matplotlib.lines.Line2D at 0x110d636a0>,
#  <matplotlib.lines.Line2D at 0x110d63a58>,
#  <matplotlib.lines.Line2D at 0x110d63f28>,
#  <matplotlib.lines.Line2D at 0x110d63e80>,
#  <matplotlib.lines.Line2D at 0x112a3e9e8>,
#  <matplotlib.lines.Line2D at 0x112a93828>,
#  <matplotlib.lines.Line2D at 0x111def048>,
#  <matplotlib.lines.Line2D at 0x111defba8>,
#  <matplotlib.lines.Line2D at 0x111e1f0f0>,
#  <matplotlib.lines.Line2D at 0x111e1ff98>,
#  <matplotlib.lines.Line2D at 0x111e1f9b0>,
#  <matplotlib.lines.Line2D at 0x111e1f7f0>,
#  <matplotlib.lines.Line2D at 0x111e1f550>,
#  <matplotlib.lines.Line2D at 0x111e1fa58>,
#  <matplotlib.lines.Line2D at 0x111e1f400>,
#  <matplotlib.lines.Line2D at 0x111e1ff60>,
#  <matplotlib.lines.Line2D at 0x111dfb710>,
#  <matplotlib.lines.Line2D at 0x111dfbe10>,
#  <matplotlib.lines.Line2D at 0x111dfb940>,
#  <matplotlib.lines.Line2D at 0x112205a20>,
#  <matplotlib.lines.Line2D at 0x112205cc0>,
#  <matplotlib.lines.Line2D at 0x110bc0278>,
#  <matplotlib.lines.Line2D at 0x110bc0940>,
#  <matplotlib.lines.Line2D at 0x110bc0f28>,
#  <matplotlib.lines.Line2D at 0x110bc0208>,
#  <matplotlib.lines.Line2D at 0x110bc08d0>,
#  <matplotlib.lines.Line2D at 0x110bc06a0>,
#  <matplotlib.lines.Line2D at 0x110bc06d8>,
#  <matplotlib.lines.Line2D at 0x110bc0e10>,
#  <matplotlib.lines.Line2D at 0x111dd75f8>,
#  <matplotlib.lines.Line2D at 0x111dd7940>,
#  <matplotlib.lines.Line2D at 0x117093400>,
#  <matplotlib.lines.Line2D at 0x117093f98>,
#  <matplotlib.lines.Line2D at 0x1170939e8>,
#  <matplotlib.lines.Line2D at 0x117093240>,
#  <matplotlib.lines.Line2D at 0x1170933c8>,
#  <matplotlib.lines.Line2D at 0x117093710>,
#  <matplotlib.lines.Line2D at 0x1170939b0>,
#  <matplotlib.lines.Line2D at 0x117093b00>,
#  <matplotlib.lines.Line2D at 0x1170480b8>,
#  <matplotlib.lines.Line2D at 0x117048518>,
#  <matplotlib.lines.Line2D at 0x117048320>,
#  <matplotlib.lines.Line2D at 0x117048cc0>,
#  <matplotlib.lines.Line2D at 0x1170481d0>,
#  <matplotlib.lines.Line2D at 0x117048e10>,
#  <matplotlib.lines.Line2D at 0x117048860>,
#  <matplotlib.lines.Line2D at 0x1125c1fd0>,
#  <matplotlib.lines.Line2D at 0x1125c12b0>,
#  <matplotlib.lines.Line2D at 0x1125c16a0>,
#  <matplotlib.lines.Line2D at 0x1125c1be0>,
#  <matplotlib.lines.Line2D at 0x1125c1048>,
#  <matplotlib.lines.Line2D at 0x1125c19e8>,
#  <matplotlib.lines.Line2D at 0x1125c15f8>,
#  <matplotlib.lines.Line2D at 0x1125c1518>,
#  <matplotlib.lines.Line2D at 0x111e60d30>,
#  <matplotlib.lines.Line2D at 0x112acf940>,
#  <matplotlib.lines.Line2D at 0x1129234a8>,
#  <matplotlib.lines.Line2D at 0x112923ac8>,
#  <matplotlib.lines.Line2D at 0x1129235f8>,
#  <matplotlib.lines.Line2D at 0x112923780>,
#  <matplotlib.lines.Line2D at 0x1129236a0>,
#  <matplotlib.lines.Line2D at 0x112923748>,
#  <matplotlib.lines.Line2D at 0x112923048>,
#  <matplotlib.lines.Line2D at 0x1125be358>,
#  <matplotlib.lines.Line2D at 0x1125beb38>,
#  <matplotlib.lines.Line2D at 0x1125beef0>,
#  <matplotlib.lines.Line2D at 0x1125be2e8>,
#  <matplotlib.lines.Line2D at 0x1125be1d0>,
#  <matplotlib.lines.Line2D at 0x1125bec50>,
#  <matplotlib.lines.Line2D at 0x1125be940>,
#  <matplotlib.lines.Line2D at 0x1125beb00>,
#  <matplotlib.lines.Line2D at 0x11305b0f0>,
#  <matplotlib.lines.Line2D at 0x11305b080>,
#  <matplotlib.lines.Line2D at 0x11305b518>,
#  <matplotlib.lines.Line2D at 0x11305b860>,
#  <matplotlib.lines.Line2D at 0x11305b9e8>,
#  <matplotlib.lines.Line2D at 0x11305bb00>,
#  <matplotlib.lines.Line2D at 0x11305b9b0>,
#  <matplotlib.lines.Line2D at 0x11305b5c0>,
#  <matplotlib.lines.Line2D at 0x112212160>,
#  <matplotlib.lines.Line2D at 0x1122121d0>,
#  <matplotlib.lines.Line2D at 0x112212668>,
#  <matplotlib.lines.Line2D at 0x112212ba8>,
#  <matplotlib.lines.Line2D at 0x112212ac8>,
#  <matplotlib.lines.Line2D at 0x112212828>,
#  <matplotlib.lines.Line2D at 0x116c58e48>,
#  <matplotlib.lines.Line2D at 0x116c58358>,
#  <matplotlib.lines.Line2D at 0x116c58f28>,
#  <matplotlib.lines.Line2D at 0x116c58b00>,
#  <matplotlib.lines.Line2D at 0x116c58c88>,
#  <matplotlib.lines.Line2D at 0x116c58f98>,
#  <matplotlib.lines.Line2D at 0x116c58b38>,
#  <matplotlib.lines.Line2D at 0x116c58748>,
#  <matplotlib.lines.Line2D at 0x10d642588>,
#  <matplotlib.lines.Line2D at 0x10d642630>,
#  <matplotlib.lines.Line2D at 0x10d642e80>,
#  <matplotlib.lines.Line2D at 0x10d6424a8>,
#  <matplotlib.lines.Line2D at 0x10d642a58>,
#  <matplotlib.lines.Line2D at 0x10d6428d0>,
#  <matplotlib.lines.Line2D at 0x1136b21d0>,
#  <matplotlib.lines.Line2D at 0x1136b27b8>,
#  <matplotlib.lines.Line2D at 0x1136b2cf8>,
#  <matplotlib.lines.Line2D at 0x1136b2a58>,
#  <matplotlib.lines.Line2D at 0x1136b2550>,
#  <matplotlib.lines.Line2D at 0x1136b2208>,
#  <matplotlib.lines.Line2D at 0x1136b26a0>,
#  <matplotlib.lines.Line2D at 0x1136b2d68>,
#  <matplotlib.lines.Line2D at 0x112ae0b00>,
#  <matplotlib.lines.Line2D at 0x112ae0908>,
#  <matplotlib.lines.Line2D at 0x112ae0860>,
#  <matplotlib.lines.Line2D at 0x112ae09b0>,
#  <matplotlib.lines.Line2D at 0x112ae0e10>,
#  <matplotlib.lines.Line2D at 0x112ae0c88>,
#  <matplotlib.lines.Line2D at 0x112ae0898>,
#  <matplotlib.lines.Line2D at 0x112ae08d0>,
#  <matplotlib.lines.Line2D at 0x112c01588>,
#  <matplotlib.lines.Line2D at 0x112c017b8>,
#  <matplotlib.lines.Line2D at 0x112c01748>,
#  <matplotlib.lines.Line2D at 0x112c01a90>,
#  <matplotlib.lines.Line2D at 0x112c01358>,
#  <matplotlib.lines.Line2D at 0x112c01da0>,
#  <matplotlib.lines.Line2D at 0x112c019b0>,
#  <matplotlib.lines.Line2D at 0x112c01160>,
#  <matplotlib.lines.Line2D at 0x113f90e10>,
#  <matplotlib.lines.Line2D at 0x113f90ef0>,
#  <matplotlib.lines.Line2D at 0x113f90400>,
#  <matplotlib.lines.Line2D at 0x113f90e48>,
#  <matplotlib.lines.Line2D at 0x113f90048>,
#  <matplotlib.lines.Line2D at 0x113f90cc0>,
#  <matplotlib.lines.Line2D at 0x113f907f0>,
#  <matplotlib.lines.Line2D at 0x111ea7668>,
#  <matplotlib.lines.Line2D at 0x112c25748>,
#  <matplotlib.lines.Line2D at 0x112c25940>,
#  <matplotlib.lines.Line2D at 0x116db1b00>,
#  <matplotlib.lines.Line2D at 0x116db1828>,
#  <matplotlib.lines.Line2D at 0x116db1da0>,
#  <matplotlib.lines.Line2D at 0x116db19e8>,
#  <matplotlib.lines.Line2D at 0x116db1fd0>,
#  <matplotlib.lines.Line2D at 0x116db1630>,
#  <matplotlib.lines.Line2D at 0x116db12b0>,
#  <matplotlib.lines.Line2D at 0x116db10f0>,
#  <matplotlib.lines.Line2D at 0x115790be0>,
#  <matplotlib.lines.Line2D at 0x115790c18>,
#  <matplotlib.lines.Line2D at 0x115790048>,
#  <matplotlib.lines.Line2D at 0x115790128>,
#  <matplotlib.lines.Line2D at 0x115790a58>,
#  <matplotlib.lines.Line2D at 0x115790470>,
#  <matplotlib.lines.Line2D at 0x115790b70>,
#  <matplotlib.lines.Line2D at 0x1157905f8>,
#  <matplotlib.lines.Line2D at 0x116d882b0>,
#  <matplotlib.lines.Line2D at 0x116d88780>,
#  <matplotlib.lines.Line2D at 0x116d88128>,
#  <matplotlib.lines.Line2D at 0x116d88e10>,
#  <matplotlib.lines.Line2D at 0x116d88eb8>,
#  <matplotlib.lines.Line2D at 0x116d88710>,
#  <matplotlib.lines.Line2D at 0x116d88550>,
#  <matplotlib.lines.Line2D at 0x116d885f8>,
#  <matplotlib.lines.Line2D at 0x112a62c88>,
#  <matplotlib.lines.Line2D at 0x1130814a8>,
#  <matplotlib.lines.Line2D at 0x1130810b8>,
#  <matplotlib.lines.Line2D at 0x113081d68>,
#  <matplotlib.lines.Line2D at 0x113081048>,
#  <matplotlib.lines.Line2D at 0x113081ef0>,
#  <matplotlib.lines.Line2D at 0x113081c18>,
#  <matplotlib.lines.Line2D at 0x113081c50>,
#  <matplotlib.lines.Line2D at 0x1125bbcc0>,
#  <matplotlib.lines.Line2D at 0x1125bb208>,
#  <matplotlib.lines.Line2D at 0x1125bbfd0>,
#  <matplotlib.lines.Line2D at 0x1125bb128>,
#  <matplotlib.lines.Line2D at 0x1125bbb70>,
#  <matplotlib.lines.Line2D at 0x1125bbba8>,
#  <matplotlib.lines.Line2D at 0x1125bbbe0>,
#  <matplotlib.lines.Line2D at 0x1116ef5c0>,
#  <matplotlib.lines.Line2D at 0x1116ef358>,
#  <matplotlib.lines.Line2D at 0x1116efbe0>,
#  <matplotlib.lines.Line2D at 0x1116ef860>,
#  <matplotlib.lines.Line2D at 0x1116ef3c8>,
#  <matplotlib.lines.Line2D at 0x1116efef0>,
#  <matplotlib.lines.Line2D at 0x110b9fbe0>,
#  <matplotlib.lines.Line2D at 0x110b9f198>,
#  <matplotlib.lines.Line2D at 0x110b9fda0>,
#  <matplotlib.lines.Line2D at 0x110b9f1d0>,
#  <matplotlib.lines.Line2D at 0x110b9f0b8>,
#  <matplotlib.lines.Line2D at 0x110b9fe48>,
#  <matplotlib.lines.Line2D at 0x110b9f6a0>,
#  ...]

# %%
Y = zeros((len(t), draws))
for k in range(draws):
    Y[:,k] = modelfun(t, *Phat[:,k])
    
figure(4)
errorbar(t, x, sigma*ones_like(t), fmt="ro")
plot(t, Y, "g", alpha=0.01);
